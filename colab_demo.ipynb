# %% [markdown]
# # Xelqara Cortex — Free Mobile Demo
# Run this notebook in Google Colab. It uses no API key and no paid service.

# %%
# !git clone https://github.com/xelqara/Xelqara-Cortex.git
# %cd Xelqara-Cortex
# !python3 -m pip install -e .
# !python3 -m unittest discover -s tests -v

# %%
arabic_text = '''
تحتفظ شركة Xelqara بالوثائق المعتمدة داخل بيئة خاصة.
لا يتم إرسال بيانات العملاء إلى خدمات خارجية.
يجب مراجعة الأدلة قبل اتخاذ أي قرار مهم.
'''
with open('arabic_context.md', 'w', encoding='utf-8') as f:
    f.write(arabic_text)
# !python3 -m xelqara_cortex.cli --root /tmp/cortex-demo ingest arabic_context.md --name arabic_context.md
# !python3 -m xelqara_cortex.cli --root /tmp/cortex-demo ask "أين تحتفظ الشركة بالوثائق؟"

# %%
# !python3 -m xelqara_cortex.cli --root /tmp/cortex-demo remember "يفضل المستخدم إجابات عربية واضحة ومختصرة." --kind preference
# !python3 -m xelqara_cortex.cli --root /tmp/cortex-demo memories
